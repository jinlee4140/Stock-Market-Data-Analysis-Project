# %% [markdown]
# I will use pandas library to get stock information, visualize different aspects of it, and I will look at a few ways of analyzing the risk of a stock, based on its previous history.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import Series,DataFrame

# %%
from datetime import datetime
from __future__ import division

# %%
from pandas.io.data import DataReader

# %%
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

# %%
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

# %%
for stock in tech_list:
    globals()[stock] = DataReader(stock,'yahoo',start,end)

# %%
AAPL
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2014-09-18  101.930000  102.349998  101.559998  101.790001   37299400
# 2014-09-19  102.290001  102.349998  100.500000  100.959999   70902400
# 2014-09-22  101.800003  102.139999  100.580002  101.059998   52788400
# 2014-09-23  100.599998  102.940002  100.540001  102.639999   63402200
# 2014-09-24  102.160004  102.849998  101.199997  101.750000   60171800
# 2014-09-25  100.510002  100.709999   97.720001   97.870003  100092000
# 2014-09-26   98.529999  100.750000   98.400002  100.750000   62370500
# 2014-09-29   98.650002  100.440002   98.629997  100.110001   49766300
# 2014-09-30  100.809998  101.540001  100.529999  100.750000   55264100
# 2014-10-01  100.589996  100.690002   98.699997   99.180000   51491300
# 2014-10-02   99.269997  100.220001   98.040001   99.900002   47757800
# 2014-10-03   99.440002  100.209999   99.040001   99.620003   43469600
# ...

# %%
AAPL.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02
# mean   118.316706  119.395436  117.072897  118.211389  5.385796e+07
# std      9.842597    9.660352    9.890759    9.771413  2.128314e+07
# min     94.870003   97.720001   92.000000   96.260002  1.447960e+07
# 25%    111.320000  112.539999  109.365002  110.377499  3.943148e+07
# 50%    118.680001  119.914997  117.720001  118.930000  4.876215e+07
# 75%    127.142502  127.907497  125.982502  126.912502  6.269118e+07
# max    134.460007  134.539993  131.399994  133.000000  1.622063e+08
#
#         Adj Close
# count  252.000000
# mean   117.214585
# std     10.001884
# min     94.642124
# 25%    110.076119
# 50%    117.704435
# 75%    126.029532
# max    131.942761

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252 entries, 2014-09-18 00:00:00 to 2015-09-17 00:00:00
# Data columns (total 6 columns):
# Open         252 non-null float64
# High         252 non-null float64
# Low          252 non-null float64
# Close        252 non-null float64
# Volume       252 non-null int64
# Adj Close    252 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB

# %%
AAPL['Adj Close'].plot(legend = True, figsize=(10,4))

# %%
AAPL['Volume'].plot(legend = True, figsize=(10,4))

# %%
ma_day = [10,20,50]

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    AAPL[column_name] = pd.rolling_mean(AAPL['Adj Close'], ma)

# %%
AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(subplots=True, figsize=(10,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x109ba8e90>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10a090b50>], dtype=object)

# %%
AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(subplots=False, figsize=(10,4))

# %% [markdown]
# As you take moving average for more days, the line gets smoother

# %%
AAPL['Daily Return'] = AAPL['Adj Close'].pct_change()

# %%
AAPL
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2014-09-18  101.930000  102.349998  101.559998  101.790001   37299400
# 2014-09-19  102.290001  102.349998  100.500000  100.959999   70902400
# 2014-09-22  101.800003  102.139999  100.580002  101.059998   52788400
# 2014-09-23  100.599998  102.940002  100.540001  102.639999   63402200
# 2014-09-24  102.160004  102.849998  101.199997  101.750000   60171800
# 2014-09-25  100.510002  100.709999   97.720001   97.870003  100092000
# 2014-09-26   98.529999  100.750000   98.400002  100.750000   62370500
# 2014-09-29   98.650002  100.440002   98.629997  100.110001   49766300
# 2014-09-30  100.809998  101.540001  100.529999  100.750000   55264100
# 2014-10-01  100.589996  100.690002   98.699997   99.180000   51491300
# 2014-10-02   99.269997  100.220001   98.040001   99.900002   47757800
# 2014-10-03   99.440002  100.209999   99.040001   99.620003   43469600
# ...

# %%
AAPL['Daily Return'].plot(figsize=(10,4), legend= True, linestyle='--', marker='o')

# %% [markdown]
# Basically, this graph is telling us that at any given day, what was your percent return on your money.

# %%
GOOG.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2014-09-18  587.002675  589.542661  585.002622  589.272695  1444600
# 2014-09-19  591.502688  596.482654  589.502696  596.082692  3736600
# 2014-09-22  593.822710  593.951665  583.462694  587.372648  1689500
# 2014-09-23  586.852606  586.852606  581.002639  581.132634  1471400
# 2014-09-24  581.462641  589.632691  580.522624  587.992634  1728100
#
#              Adj Close
# Date
# 2014-09-18  589.272695
# 2014-09-19  596.082692
# 2014-09-22  587.372648
# 2014-09-23  581.132634
# 2014-09-24  587.992634

# %%
GOOG["Adj Close"].plot(legend=True, figsize=(10,4))

# %%
YHOO = DataReader('YHOO', 'yahoo', datetime(2014, 4, 1), datetime(2015, 4, 1))

# %%
YHOO.head()
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2014-04-01  36.160000  36.860001  36.150002  36.490002  15734000  36.490002
# 2014-04-02  36.680000  36.860001  36.560001  36.639999  14522800  36.639999
# 2014-04-03  36.660000  36.790001  35.509998  35.759998  16827800  35.759998
# 2014-04-04  36.009998  36.049999  33.830002  34.259998  41049900  34.259998
# 2014-04-07  34.110001  34.369999  32.529999  33.070000  47770200  33.070000

# %%
YHOO["Adj Close"].plot(legend = True, figsize = (10,4))

# %%
ma_day = [10,20,50]

for ma in ma_day:
    column_name = "MA for %s days" %(ma)
    YHOO[column_name] = pd.rolling_mean(YHOO['Adj Close'], ma)

# %%
YHOO.head(20)
# Out:
#                  Open       High        Low      Close    Volume  Adj Close  \
# Date
# 2014-04-01  36.160000  36.860001  36.150002  36.490002  15734000  36.490002
# 2014-04-02  36.680000  36.860001  36.560001  36.639999  14522800  36.639999
# 2014-04-03  36.660000  36.790001  35.509998  35.759998  16827800  35.759998
# 2014-04-04  36.009998  36.049999  33.830002  34.259998  41049900  34.259998
# 2014-04-07  34.110001  34.369999  32.529999  33.070000  47770200  33.070000
# 2014-04-08  33.099998  34.430000  33.020000  33.830002  35486100  33.830002
# 2014-04-09  34.189999  35.000000  33.950001  34.869999  21651200  34.869999
# 2014-04-10  34.880001  34.980000  33.090000  33.400002  34024900  33.400002
# 2014-04-11  32.639999  33.480000  32.150002  32.869999  28040700  32.869999
# 2014-04-14  33.549999  34.040001  33.040001  33.450001  26322600  33.450001
# 2014-04-15  33.930000  34.279999  32.639999  34.209999  50600400  34.209999
# ...

# %%
YHOO[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(subplots = False, figsize = (10,4), legend = True)

# %%
YHOO['Daily Return'] = YHOO['Adj Close'].pct_change()

# %%
YHOO['Daily Return'].plot(legend = True, figsize= (10,4))

# %% [markdown]
# ****************************************
# sns plot

# %%
AAPL['Daily Return'].hist(bins=100)

# %%
closing_df = DataReader(tech_list, 'yahoo', start, end)['Adj Close']

# %%
closing_df.head()
# Out:
#                   AAPL        AMZN        GOOG       MSFT
# Date
# 2014-09-18  100.079178  325.000000  589.272695  45.462435
# 2014-09-19   99.263126  331.320007  596.082692  46.280525
# 2014-09-22   99.361444  324.500000  587.372648  45.832524
# 2014-09-23  100.914890  323.630005  581.132634  45.345566
# 2014-09-24  100.039849  328.209991  587.992634  45.852003

# %%
tech_returns = closing_df.pct_change()

# %%
tech_returns.head(10)
# Out:
#                 AAPL      AMZN      GOOG      MSFT
# Date
# 2014-09-18       NaN       NaN       NaN       NaN
# 2014-09-19 -0.008154  0.019446  0.011557  0.017995
# 2014-09-22  0.000990 -0.020584 -0.014612 -0.009680
# 2014-09-23  0.015634 -0.002681 -0.010624 -0.010625
# 2014-09-24 -0.008671  0.014152  0.011805  0.011168
# 2014-09-25 -0.038133 -0.019134 -0.021990 -0.022090
# 2014-09-26  0.029427  0.003976  0.003547  0.008036
# 2014-09-29 -0.006352 -0.004301 -0.001282  0.000646
# 2014-09-30  0.006393  0.001927  0.001735 -0.001723
# 2014-10-01 -0.015583 -0.015445 -0.015744 -0.009922

# %% [markdown]
# **********************************************
# sns plot
